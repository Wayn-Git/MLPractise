# %%
import torch

# %%
t1 = torch.tensor([1,2,3])

print(t1)
# Out:
# tensor([1, 2, 3])

# %%
t2 = torch.tensor([[2,3],[2,3]])
print(t2)
# Out:
# tensor([[2, 3],
#         [2, 3]])

# %%
rand_t3 = torch.rand(2,3)

print(rand_t3)
# Out:
# tensor([[0.7692, 0.5688, 0.6767],
#         [0.3758, 0.6959, 0.6437]])

# %%
zero_t4 = torch.zeros(2,3)

print(zero_t4)
# Out:
# tensor([[0., 0., 0.],
#         [0., 0., 0.]])

# %%
tensor = torch.tensor([[1,2], [3,4], [5,6]])

element = tensor[1][0]

print(element) # indexing bruh

slice_ten = tensor[:2, :]

print(slice_ten)

print(tensor)

res_ten = tensor.view(2,3)

print(res_ten)
# Out:
# tensor(3)
# tensor([[1, 2],
#         [3, 4]])
# tensor([[1, 2],
#         [3, 4],
#         [5, 6]])
# tensor([[1, 2, 3],
#         [4, 5, 6]])

# %%
ta1 = torch.tensor([[2,3,4],[5,6,7]])
ta2 = torch.tensor([2,3,4])
add = ta1 + ta2

print(ta1)
print()
print(ta2)
print()
print(add)
# Out:
# tensor([[2, 3, 4],
#         [5, 6, 7]])
#
# tensor([2, 3, 4])
#
# tensor([[ 4,  6,  8],
#         [ 7,  9, 11]])

# %%
import torch
print(torch.cuda.is_available())
print(torch.cuda.device_count())
print(torch.cuda.get_device_name(0))
# Out:
# True
# 1
# NVIDIA GeForce RTX 4050 Laptop GPU

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

print(device)
# Out:
# cpu

# %%
import torch

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

print(device)
# Out:
# cuda

# %%
import numpy as np
import matplotlib.pyplot as plt

X = np.array([x for x in range(100)])

X.reshape(-1,1)



y = 74 + 89 * X.flatten()


y
# Out:
# array([  74,  163,  252,  341,  430,  519,  608,  697,  786,  875,  964,
#        1053, 1142, 1231, 1320, 1409, 1498, 1587, 1676, 1765, 1854, 1943,
#        2032, 2121, 2210, 2299, 2388, 2477, 2566, 2655, 2744, 2833, 2922,
#        3011, 3100, 3189, 3278, 3367, 3456, 3545, 3634, 3723, 3812, 3901,
#        3990, 4079, 4168, 4257, 4346, 4435, 4524, 4613, 4702, 4791, 4880,
#        4969, 5058, 5147, 5236, 5325, 5414, 5503, 5592, 5681, 5770, 5859,
#        5948, 6037, 6126, 6215, 6304, 6393, 6482, 6571, 6660, 6749, 6838,
#        6927, 7016, 7105, 7194, 7283, 7372, 7461, 7550, 7639, 7728, 7817,
#        7906, 7995, 8084, 8173, 8262, 8351, 8440, 8529, 8618, 8707, 8796,
#        8885])

# %%
plt.scatter(X, y)
plt.title("Linear Relation")
plt.xlabel("X")
plt.ylabel("y")
plt.legend()
plt.show()
# Out:
# C:\Users\Wayne\AppData\Local\Temp\ipykernel_7552\2184201558.py:5: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
# Understanding the super method


class Dog:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def say_name(self):
        return self.name
    
class Cat(Dog):
    def __init__(self, name, age):
        super().__init__(name, age)

    def info(self):
        return self.name

obj_Dog = Dog("Bilal", 1)
obj_Cat = Cat("Kitty", 2)

print(obj_Dog.say_name())
print(obj_Cat.info())
# Out:
# Bilal
# Kitty

# %%
import torch.nn as nn
import torch.optim as optim

class LinearRegression(nn.Module):
    def __init__(self, in_features, out_features):
        super().__init__()
        self.linear = nn.Linear(in_features, out_features)

    def forward(self, x):
        return self.linear(x).squeeze(1)

# %%
infeatures = 1
outfeatures = 1 

model = LinearRegression(infeatures, outfeatures)

# %%
criterion = nn.MSELoss()
optimizer = optim.SGD(model.parameters(), lr=0.1)

# Parameter =
